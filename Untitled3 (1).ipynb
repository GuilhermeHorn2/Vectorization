# %%
import cv2 as cv
from matplotlib import pyplot as plt
import numpy as np

# %%
img = np.matrix(cv.imread('dog.jpg',0))

# %%
tmp = img.reshape(1,img.shape[0]*img.shape[1])
print(tmp)
plt.style.use('fivethirtyeight')
# Out:
# [[ 68  64  61 ... 202 200 197]]

# %%
plt.hist(tmp[0],bins=10,edgecolor='black');
